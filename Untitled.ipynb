# %%
import pandas as pd

# %%
pip install sqlalchemy psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
df = pd.read_csv('green_tripdata_2019-09.csv.gz')
# df = pd.read_csv('taxi+_zone_lookup')
# Out:
# /tmp/ipykernel_6381/2430429997.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('green_tripdata_2019-09.csv.gz')

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# 1         1.0            97           225              5.0           3.20
# 2         1.0            37            61              5.0           2.99
# 3         1.0           145           112              1.0           1.73
# 4         1.0           112           198              1.0           3.42
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.tail()
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 449058       NaN  2019-09-30 23:13:00   2019-09-30 23:41:00
# 449059       NaN  2019-09-30 23:26:00   2019-09-30 23:46:00
# 449060       NaN  2019-09-30 23:15:00   2019-09-30 23:43:00
# 449061       NaN  2019-09-30 23:19:00   2019-10-01 00:06:00
# 449062       NaN  2019-09-30 23:35:00   2019-09-30 23:58:00
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 449058                NaN         NaN            66            71
# 449059                NaN         NaN            55            26
# 449060                NaN         NaN           139            78
# 449061                NaN         NaN           242           188
# 449062                NaN         NaN           155           189
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 449058              NaN           7.84        43.25   2.75      0.5
# ...

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
# Out:
# /tmp/ipykernel_6381/3869521473.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.tpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)
# /tmp/ipykernel_6381/3869521473.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.tpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)

# %%
df.to_sql(name='green_tripdata', con=engine, index=False)

# %%
query = """
SELECT * FROM green_tripdata limit 10
"""

pd.read_sql(query, con=engine)
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0       2.0  2019-09-01 00:10:53   2019-09-01 00:23:46                  N
# 1       2.0  2019-09-01 00:31:22   2019-09-01 00:44:37                  N
# 2       2.0  2019-09-01 00:50:24   2019-09-01 01:03:20                  N
# 3       2.0  2019-09-01 00:27:06   2019-09-01 00:33:22                  N
# 4       2.0  2019-09-01 00:43:23   2019-09-01 00:59:54                  N
# 5       2.0  2019-09-01 00:55:37   2019-09-01 01:17:02                  N
# 6       2.0  2019-09-01 00:28:55   2019-09-01 00:52:09                  N
# 7       1.0  2019-09-01 00:03:13   2019-09-01 00:03:32                  N
# 8       1.0  2019-09-01 00:15:28   2019-09-01 00:43:22                  N
# 9       2.0  2019-09-01 00:29:16   2019-09-01 00:30:15                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            65           189              5.0           2.00
# ...

# %%
df = pd.read_csv('taxi+_zone_lookup.csv')
df.to_sql(name='taxi_zone_lookup', con=engine, index=False)
# Out:
# 265

# %%
query= """SELECT * FROM taxi_zone_lookup limit 10
"""
pd.read_sql(query, con=engine)
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone
# 5           6  Staten Island  Arrochar/Fort Wadsworth    Boro Zone
# 6           7         Queens                  Astoria    Boro Zone
# 7           8         Queens             Astoria Park    Boro Zone
# 8           9         Queens               Auburndale    Boro Zone
# 9          10         Queens             Baisley Park    Boro Zone
